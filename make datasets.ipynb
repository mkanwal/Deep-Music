# %%
import midi
import numpy as np
import h5py
class MidiContainer:
    '''
    The MidiContainer class contains a vector representation of 
    the midi track to be fed to our neural net. It is a 67 x n matrix,
    contents specified in the README. 
    '''
    def __init__(self):
        self.data = np.array([], dtype=np.int64).reshape(66,0) 
        self.curr_bpm = 120
        self.curr_instrument = 0
        self.abs_time = 0
        self.active_pitches = {} #[pitch] = (velocity, time note was turned on)
        
    def note_to_vector(self, pitch, time):
        velocity = self.active_pitches[pitch][0]
        note_start = self.active_pitches[pitch][1]
        return np.vstack((self.curr_instrument, pitch, velocity, time + self.abs_time - note_start))
    
    def add_data(self, note_vector, note_start):
        event_column = np.vstack((note_start, self.curr_bpm, note_vector, np.ones((60,1))*-1))
        self.data = np.hstack((self.data, event_column))
    
    def combine_tracks(self):
        self.data = self.data.T[self.data.T[:, 0].argsort()].T #maybe we dont need so many transposes
        prev_duration = -1
        edit_index = 0 
        i = 0
        delete_this = []
        old_inst = self.data[2,0]
        for col in self.data.T:
            curr_duration = col[0]
            if curr_duration == prev_duration:
                for ni in xrange(2,67,4):
                    note_vec = col[ni:ni+4]
                    curr_inst = note_vec[0] if note_vec.any() else -1
                    if np.sum(note_vec) > 0 and curr_inst != old_inst:
                        i_rep = np.where(self.data[:,edit_index] == -1)[0][0]
                        self.data[i_rep:i_rep+4, edit_index] = note_vec
                        delete_this.append(i)
            else:
                old_inst = col[2]
                edit_index = i
            i += 1 
            prev_duration = curr_duration
            
        mask = np.ones(self.data.shape, np.bool)
        mask[:,delete_this] = 0
        self.data = self.data[mask].reshape(66,-1)
       
                
    
def midi_to_vector(fname):
    '''
    Given a filename of a midi to read, returns a MidiContainer object of its vector representation.
    '''
    pattern = midi.read_midifile(fname)
    midi_vector = MidiContainer()
    for track in pattern:
        midi_vector.abs_time = 0
        for event in track:
            if isinstance(event, midi.SetTempoEvent): 
                midi_vector.curr_bpm = event.get_bpm()
            if isinstance(event, midi.EndOfTrackEvent): #first metadata track
                continue 
            if isinstance(event, midi.ProgramChangeEvent):
                midi_vector.curr_instrument = event.get_value()
            if isinstance(event, midi.NoteOnEvent):
                midi_vector.abs_time += event.tick
                midi_vector.active_pitches[event.get_pitch()] = (event.get_velocity(), midi_vector.abs_time)
            if isinstance(event, midi.NoteOffEvent):
                pitch = event.get_pitch()
                time = event.tick
                if pitch in midi_vector.active_pitches:
                    note_vec = midi_vector.note_to_vector(pitch, time)
                    midi_vector.add_data(note_vec, midi_vector.active_pitches[pitch][1]) #ugh bad data abstraction
                    midi_vector.active_pitches.pop(pitch, None)
                    midi_vector.abs_time += event.tick
                    
#     assert midi_vector.data.all(), "Read midifile is empty."            
    midi_vector.combine_tracks()        
    return midi_vector

def vector_to_midi(vector):
    '''Given a np array (vector.data), returns a python midi pattern'''
    pattern = midi.Pattern(resolution=192)
    #first, separate tracks
    tracklist = {}
    for i in xrange(2,vector.shape[0],4):
        for j in xrange(0, vector.shape[1]):
            track = vector[i:i+4,j]
            if np.sum(track) > 0:
                instrument = int(track[0])
                if instrument not in tracklist:
                    tracklist[instrument] = np.vstack((vector[0:2,j].reshape(-1,1), track.reshape(-1,1)))
                else: 
                    tracklist[instrument] = np.hstack((tracklist[instrument], np.vstack((vector[0:2,j].reshape(-1,1), track.reshape(-1,1)))))


    for k, track in tracklist.iteritems():
        miditrack = midi.Track()
        pattern.append(miditrack)
        bpm = track[1,0]
        tempoevent = midi.SetTempoEvent(tick=0, bpm=bpm)
        miditrack.append(tempoevent)
        instrument = int(track[2,0])
        fontevent = midi.ProgramChangeEvent(tick=0, value=instrument)
        miditrack.append(fontevent)
        if not np.array_equal(bpm * np.ones(track.shape[1]), track[1,:]):
            print 'Tempo changes. Code assumes it doesn\'t. Contact Jingyi.'
        
        event_tick = 0   
        track_duration = np.max(track[0,:] + track[-1,:])
        active_notes = {}
        start_times = track[0,:]
        for t in xrange(0, int(track_duration)+1):
            for pitch in active_notes:
                active_notes[pitch] -= 1
            
            negs = [k for k,v in active_notes.iteritems() if v < 0]
            for n in negs:
                active_notes.pop(n)
                
            while 0 in active_notes.values():
                pitches = [k for k,v in active_notes.iteritems() if v == 0]
                for pitch in pitches:
                    off = midi.NoteOffEvent(tick=t - event_tick, pitch=pitch)
                    miditrack.append(off)
                    active_notes.pop(pitch)
                    event_tick = t
                    
            #run through track to add on/off events
            if t in start_times:
                ni = np.where(t == start_times)
                for n in ni[0]:
                    note = track[:, n]
                    start_time = int(note[0])
                    pitch = int(note[3])
                    velocity = int(note[4])
                    duration = int(note[5])
                    active_notes[pitch] = duration
                    on = midi.NoteOnEvent(tick = t - event_tick, velocity=velocity, pitch=pitch)
                    miditrack.append(on)
                    event_tick = start_time
                    
        miditrack.append(midi.EndOfTrackEvent(tick=0))
    return pattern

# %%
path = '/Users/noon/Desktop/midis/broadway/' #change me, make sure to make a 'data' folder
import os
i = 0
b = 1
for fname in os.listdir(path):
    if '.mid' in fname.lower():
        try:
            vectorized = midi_to_vector(path+fname)
            h5f = h5py.File(path+'data/'+fname[0:-4]+'.h5', 'w')
            h5f.create_dataset('dataset_1', data=vectorized.data)
            h5f.close()
            print 'SUCCESS! finished writing for ', fname
            i += 1
        except (TypeError, AssertionError, IndexError) as e:
            print e, fname
            b += 1
            continue
b-=1
print 'got ', i*1.0/(i+b) * 100, '% working'
# Out:
# SUCCESS! finished writing for  aliaskyu.mid
# index 0 is out of bounds for axis 1 with size 0 almostlk.mid
# index 0 is out of bounds for axis 1 with size 0 america.mid
# SUCCESS! finished writing for  angel.mid
# index 0 is out of bounds for axis 1 with size 0 baliha'i.mid
# index 0 is out of bounds for axis 1 with size 0 belinyou.mid
# index 0 is out of bounds for axis 1 with size 0 bring.mid
# SUCCESS! finished writing for  broadway.mid
# index 0 is out of bounds for axis 1 with size 0 cabaret.mid
# index 0 is out of bounds for axis 1 with size 0 castle.mid
# SUCCESS! finished writing for  chess.mid
# index 0 is out of bounds for axis 1 with size 0 close.mid
# index 0 is out of bounds for axis 1 with size 0 crapshot.mid
# SUCCESS! finished writing for  ditesmoi.mid
# index 0 is out of bounds for axis 1 with size 0 dolly.mid
# index 0 is out of bounds for axis 1 with size 0 domphan.mid
# index 0 is out of bounds for axis 1 with size 0 dphanrk.mid
# SUCCESS! finished writing for  eapoe.mid
# SUCCESS! finished writing for  edelweis.mid
# SUCCESS! finished writing for  eternal.mid
# SUCCESS! finished writing for  evita.mid
# SUCCESS! finished writing for  fantast.mid
# SUCCESS! finished writing for  getoknow.mid
# index 0 is out of bounds for axis 1 with size 0 guydolls.mid
# SUCCESS! finished writing for  hapevaf.mid
# index 0 is out of bounds for axis 1 with size 0 hearsing.mid
# SUCCESS! finished writing for  hernando.mid
# SUCCESS! finished writing for  heythere.mid
# SUCCESS! finished writing for  hndohdwy.mid
# SUCCESS! finished writing for  hopeless.mid
# index 0 is out of bounds for axis 1 with size 0 magctodo.mid
# SUCCESS! finished writing for  maria.mid
# SUCCESS! finished writing for  mhbring.mid
# SUCCESS! finished writing for  music.mid
# SUCCESS! finished writing for  noinlove.mid
# SUCCESS! finished writing for  oncewasa.mid
# SUCCESS! finished writing for  onceyear.mid
# index 0 is out of bounds for axis 1 with size 0 peoplew.mid
# index 0 is out of bounds for axis 1 with size 0 phantom2.mid
# index 0 is out of bounds for axis 1 with size 0 river.mid
# SUCCESS! finished writing for  smaltalk.mid
# SUCCESS! finished writing for  steam.mid
# SUCCESS! finished writing for  tinhorn.mid
# SUCCESS! finished writing for  youcando.mid
# got  59.0909090909 % working

# %%
def gen_channel():
    font = np.random.random_integers(0,127, size=(1,500))
    note = np.random.random_integers(0,127, size=(1,500))
    vel = np.random.random_integers(0,255, size=(1,500))
    duration = np.random.random_integers(0,1000, size=(1,500))
    return np.vstack((font, note, vel, duration))

def gen_random_midi():
    times = np.random.random_integers(0,1000, size=(1,500))
    bpm = np.random.random_integers(50,300) * np.ones((1,500))
    midi = np.vstack((times,bpm))
    for i in xrange(0,16):
        midi = np.vstack((midi, gen_channel()))
    return midi

# %%
#random generation test

data = gen_random_midi()
print data
pattern = vector_to_midi(data)
print pattern
midi.write_midifile('rando.mid', pattern)
# Out:
# [[ 818.  752.  312. ...,  114.  975.  535.]
#  [ 103.  103.  103. ...,  103.  103.  103.]
#  [  86.   24.   85. ...,   61.   78.  118.]
#  ...,
#  [  27.    8.   66. ...,   14.  112.   27.]
#  [  54.   12.  196. ...,  227.   17.  158.]
#  [ 554.  553.  871. ...,  912.  985.  582.]]
# midi.Pattern(format=1, resolution=192, tracks=\
# [midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[5, 91]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[61, 58]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[30, 223]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[79, 141]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[76, 139]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[5, 0]),
#    midi.NoteOnEvent(tick=25, channel=0, data=[114, 23]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[26, 113]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[82, 58]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[99, 54]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[116, 53]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[13, 98]),
#    midi.NoteOnEvent(tick=45, channel=0, data=[120, 64]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[52, 28]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[48, 17]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[59, 183]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 82]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[2, 214]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[116, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[109, 102]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[48, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[79, 18]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[109, 0]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[109, 39]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[97, 73]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[125, 236]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 117]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[14, 32]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[22, 202]),
#    midi.NoteOnEvent(tick=42, channel=0, data=[32, 194]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[109, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[48, 196]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[18, 248]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[101, 226]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[48, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[0, 219]),
#    midi.NoteOffEvent(tick=45, channel=0, data=[120, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[52, 240]),
#    midi.NoteOnEvent(tick=26, channel=0, data=[125, 180]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[94, 181]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[47, 18]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[114, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[62, 121]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[0, 0]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[12, 139]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[27, 167]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[72, 154]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[124, 180]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[63, 139]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[65, 5]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[1, 181]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[124, 31]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[94, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[59, 194]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[1, 255]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[63, 164]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[20, 3]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[37, 89]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[95, 177]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[79, 0]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[31, 96]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[63, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[55, 74]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[23, 199]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[4, 48]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[22, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[99, 34]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[117, 244]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[15, 193]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[62, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[62, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[58, 34]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[102, 4]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[76, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[47, 152]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[58, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[58, 176]),
#    midi.NoteOnEvent(tick=44, channel=0, data=[127, 184]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[1, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[124, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[116, 36]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[26, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[93, 67]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[65, 43]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[99, 234]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[27, 0]),
#    midi.NoteOnEvent(tick=35, channel=0, data=[45, 212]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[81, 89]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[83, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[45, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=24, channel=0, data=[31, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[97, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[125, 0]),
#    midi.NoteOffEvent(tick=51, channel=0, data=[72, 0]),
#    midi.NoteOffEvent(tick=40, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[99, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[2, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[12, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[65, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[101, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[52, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[20, 0]),
#    midi.NoteOffEvent(tick=56, channel=0, data=[95, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[14, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[23, 0]),
#    midi.NoteOffEvent(tick=43, channel=0, data=[15, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=132, channel=0, data=[59, 0]),
#    midi.NoteOffEvent(tick=43, channel=0, data=[81, 0]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[62, 0]),
#    midi.NoteOffEvent(tick=57, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=47, channel=0, data=[127, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[47, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[58, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[116, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[1]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[80, 76]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[37, 155]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[41, 91]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[37, 0]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[124, 186]),
#    midi.NoteOnEvent(tick=44, channel=0, data=[101, 145]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[53, 175]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[66, 147]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[53, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[71, 157]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[83, 196]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[54, 239]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[38, 30]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[121, 143]),
#    midi.NoteOnEvent(tick=25, channel=0, data=[61, 36]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[121, 24]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[35, 174]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[26, 79]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[106, 231]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[39, 88]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[66, 0]),
#    midi.NoteOnEvent(tick=49, channel=0, data=[48, 90]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[1, 237]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[101, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[10, 233]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[34, 91]),
#    midi.NoteOnEvent(tick=75, channel=0, data=[33, 161]),
#    midi.NoteOffEvent(tick=24, channel=0, data=[80, 0]),
#    midi.NoteOnEvent(tick=27, channel=0, data=[37, 179]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[71, 186]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[18, 235]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[121, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[55, 203]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[106, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[19, 21]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[24, 147]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[83, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[34, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[48, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[76, 161]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[16, 96]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[117, 231]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[41, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[71, 15]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[33, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[100, 92]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[24, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[58, 109]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[18, 127]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[54, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[116, 79]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[107, 91]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[107, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[104, 209]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[7, 248]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[55, 90]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[116, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[124, 0]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[68, 245]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[93, 163]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[115, 133]),
#    midi.NoteOffEvent(tick=39, channel=0, data=[1, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[38, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[7, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[60, 9]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[16, 0]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[9, 129]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[60, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[53, 33]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[53, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[82, 212]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[115, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[104, 18]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[8, 56]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[60, 45]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[106, 228]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[39, 0]),
#    midi.NoteOffEvent(tick=125, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=67, channel=0, data=[26, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[10, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[58, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=61, channel=0, data=[71, 0]),
#    midi.NoteOffEvent(tick=145, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[76, 0]),
#    midi.NoteOffEvent(tick=49, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[104, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[100, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=186, channel=0, data=[8, 0]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[60, 0]),
#    midi.NoteOffEvent(tick=84, channel=0, data=[9, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[106, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[2]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[53, 85]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[5, 92]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[102, 107]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[126, 204]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[85, 190]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[84, 203]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[9, 221]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[96, 130]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[50, 67]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[11, 155]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[76, 14]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[16, 243]),
#    midi.NoteOnEvent(tick=35, channel=0, data=[16, 168]),
#    midi.NoteOnEvent(tick=57, channel=0, data=[48, 1]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[88, 133]),
#    midi.NoteOnEvent(tick=34, channel=0, data=[35, 22]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[77, 24]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[61, 235]),
#    midi.NoteOnEvent(tick=34, channel=0, data=[108, 224]),
#    midi.NoteOffEvent(tick=29, channel=0, data=[84, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[68, 4]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[51, 35]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[126, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[11, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[13, 94]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[35, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[52, 172]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[68, 135]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[81, 253]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[13, 67]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[85, 1]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[12, 62]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[48, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[90, 205]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[32, 156]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[9, 110]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[127, 117]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[57, 25]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[15, 9]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[57, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[102, 55]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[53, 204]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[25, 120]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[19, 59]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[125, 199]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[84, 155]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[75, 71]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[115, 46]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[77, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[22, 217]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[127, 0]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[109, 215]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[103, 35]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[39, 216]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[105, 87]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[118, 176]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[27, 161]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=46, channel=0, data=[115, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[46, 153]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[15, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[94, 156]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[12, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[39, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[57, 196]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[103, 0]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[14, 171]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[11, 15]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[106, 125]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[36, 228]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[118, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[36, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[84, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[54, 55]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[52, 27]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[14, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[46, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[23, 68]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[96, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[98, 71]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[25, 181]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[51, 81]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[125, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[42, 47]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[76, 0]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=62, channel=0, data=[16, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[108, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[23, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[52, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[61, 0]),
#    midi.NoteOffEvent(tick=57, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=59, channel=0, data=[9, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[105, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[42, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[53, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[57, 0]),
#    midi.NoteOffEvent(tick=39, channel=0, data=[22, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[75, 0]),
#    midi.NoteOffEvent(tick=97, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=81, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=47, channel=0, data=[109, 0]),
#    midi.NoteOffEvent(tick=77, channel=0, data=[94, 0]),
#    midi.NoteOffEvent(tick=49, channel=0, data=[106, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[54, 0]),
#    midi.NoteOffEvent(tick=73, channel=0, data=[25, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[3]),
#    midi.NoteOnEvent(tick=47, channel=0, data=[48, 55]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[108, 77]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[14, 201]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[26, 28]),
#    midi.NoteOnEvent(tick=41, channel=0, data=[13, 109]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[77, 229]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[93, 66]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[85, 110]),
#    midi.NoteOnEvent(tick=24, channel=0, data=[69, 57]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[14, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[70, 127]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[29, 5]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[25, 250]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[77, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[47, 34]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[5, 24]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[34, 155]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[10, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[71, 120]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[89, 156]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[101, 2]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[101, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[36, 59]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[29, 0]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[110, 217]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[32, 100]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[121, 185]),
#    midi.NoteOnEvent(tick=36, channel=0, data=[103, 195]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[3, 59]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[8, 53]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[36, 0]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[67, 181]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[10, 0]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[28, 175]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[103, 0]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[32, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[76, 132]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[121, 0]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[88, 107]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[37, 169]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[39, 2]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[108, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[43, 210]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[125, 107]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[28, 41]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[19, 16]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[35, 141]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[3, 199]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[27, 32]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[7, 33]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[66, 196]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[65, 14]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 250]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[4, 102]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[48, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[43, 69]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[78, 236]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[115, 215]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[99, 181]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[23, 120]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[32, 88]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[50, 41]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[43, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[23, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[26, 0]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[121, 135]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[117, 12]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[34, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[41, 105]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[25, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[55, 188]),
#    midi.NoteOffEvent(tick=24, channel=0, data=[27, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[18, 224]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[125, 180]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[102, 138]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[70, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[110, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[68, 66]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[44, 146]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[99, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[41, 161]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[17, 106]),
#    midi.NoteOffEvent(tick=30, channel=0, data=[3, 0]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[47, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=65, channel=0, data=[17, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[76, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[89, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[8, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[121, 0]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=45, channel=0, data=[125, 0]),
#    midi.NoteOffEvent(tick=24, channel=0, data=[65, 0]),
#    midi.NoteOffEvent(tick=107, channel=0, data=[39, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[41, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[7, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=56, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=109, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[115, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[44, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[4]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[23, 112]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[74, 43]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[98, 152]),
#    midi.NoteOnEvent(tick=47, channel=0, data=[23, 144]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[29, 165]),
#    midi.NoteOnEvent(tick=30, channel=0, data=[49, 110]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[36, 21]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[38, 42]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[100, 120]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[75, 102]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[72, 33]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[63, 52]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[67, 231]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[92, 189]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[116, 142]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[72, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[13, 205]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[101, 66]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[4, 146]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[53, 161]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[74, 155]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[100, 0]),
#    midi.NoteOnEvent(tick=25, channel=0, data=[118, 164]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[118, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[22, 174]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[115, 189]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[27, 110]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[115, 0]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[58, 99]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[32, 217]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[27, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[110, 215]),
#    midi.NoteOffEvent(tick=32, channel=0, data=[13, 0]),
#    midi.NoteOnEvent(tick=85, channel=0, data=[86, 38]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[119, 97]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[50, 29]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[54, 13]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[25, 180]),
#    midi.NoteOnEvent(tick=34, channel=0, data=[27, 49]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[21, 171]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[22, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[65, 210]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[115, 1]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[33, 104]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[58, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[81, 247]),
#    midi.NoteOnEvent(tick=35, channel=0, data=[54, 12]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[33, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[28, 174]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[19, 155]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[16, 147]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[36, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[75, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[119, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[0, 102]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[61, 188]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[92, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[111, 225]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[96, 43]),
#    midi.NoteOffEvent(tick=42, channel=0, data=[38, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[121, 200]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[68, 183]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[55, 97]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[106, 108]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[49, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[101, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[90, 225]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[19, 25]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[11, 235]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[61, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[65, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[5, 22]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[66, 197]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[25, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[62, 41]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[62, 87]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[101, 87]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[23, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[10, 140]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[35, 138]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[110, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[64, 17]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[53, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[25, 43]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[81, 137]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[75, 24]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[116, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[80, 237]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[121, 0]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[75, 30]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[84, 50]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[61, 229]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=40, channel=0, data=[115, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[0, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[63, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=30, channel=0, data=[111, 0]),
#    midi.NoteOffEvent(tick=34, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=42, channel=0, data=[54, 0]),
#    midi.NoteOffEvent(tick=75, channel=0, data=[101, 0]),
#    midi.NoteOffEvent(tick=53, channel=0, data=[75, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[106, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[84, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[81, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[21, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[16, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[64, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[96, 0]),
#    midi.NoteOffEvent(tick=71, channel=0, data=[61, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[62, 0]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[10, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[25, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[5]),
#    midi.NoteOnEvent(tick=28, channel=0, data=[35, 184]),
#    midi.NoteOnEvent(tick=40, channel=0, data=[92, 129]),
#    midi.NoteOnEvent(tick=51, channel=0, data=[99, 40]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[56, 146]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[118, 211]),
#    midi.NoteOnEvent(tick=34, channel=0, data=[40, 91]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[41, 42]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[44, 61]),
#    midi.NoteOnEvent(tick=51, channel=0, data=[41, 23]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[70, 235]),
#    midi.NoteOnEvent(tick=30, channel=0, data=[71, 15]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[118, 0]),
#    midi.NoteOnEvent(tick=70, channel=0, data=[32, 35]),
#    midi.NoteOnEvent(tick=43, channel=0, data=[30, 138]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[69, 130]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[1, 238]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[92, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[75, 214]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[33, 179]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[9, 89]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[100, 54]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[71, 0]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[74, 95]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[41, 26]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[43, 126]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[83, 248]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[10, 38]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[104, 101]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[35, 14]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[9, 224]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[96, 216]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[88, 236]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[9, 0]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[88, 41]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 15]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[76, 40]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[10, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[24, 189]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[59, 56]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[68, 15]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[58, 164]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[67, 0]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[92, 111]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[104, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[14, 226]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[44, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[104, 50]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[69, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[75, 178]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[102, 231]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[93, 58]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[92, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[62, 218]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[113, 135]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[27, 248]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[77, 69]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[29, 70]),
#    midi.NoteOnEvent(tick=35, channel=0, data=[21, 79]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[30, 78]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[58, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[45, 246]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[1, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[32, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[98, 6]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[24, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[12, 132]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[51, 49]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[99, 0]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[68, 27]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[74, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[108, 132]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[76, 228]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[104, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[56, 0]),
#    midi.NoteOffEvent(tick=71, channel=0, data=[76, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[40, 0]),
#    midi.NoteOffEvent(tick=36, channel=0, data=[70, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=30, channel=0, data=[21, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[108, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=50, channel=0, data=[43, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[96, 0]),
#    midi.NoteOffEvent(tick=55, channel=0, data=[83, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[33, 0]),
#    midi.NoteOffEvent(tick=37, channel=0, data=[100, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[14, 0]),
#    midi.NoteOffEvent(tick=49, channel=0, data=[62, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[41, 0]),
#    midi.NoteOffEvent(tick=29, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=62, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[59, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=41, channel=0, data=[113, 0]),
#    midi.NoteOffEvent(tick=71, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=94, channel=0, data=[45, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=57, channel=0, data=[12, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[6]),
#    midi.NoteOnEvent(tick=30, channel=0, data=[41, 197]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[68, 40]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[85, 39]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[63, 201]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[113, 154]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[108, 45]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[2, 128]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[93, 104]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[113, 16]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[124, 43]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[39, 205]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[61, 183]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[26, 52]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[43, 47]),
#    midi.NoteOffEvent(tick=61, channel=0, data=[108, 0]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[63, 20]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[84, 26]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[55, 114]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[86, 2]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[105, 56]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[113, 0]),
#    midi.NoteOnEvent(tick=42, channel=0, data=[81, 123]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[115, 59]),
#    midi.NoteOnEvent(tick=24, channel=0, data=[45, 45]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[41, 186]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[105, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=29, channel=0, data=[63, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[29, 110]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[56, 154]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[58, 252]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[58, 223]),
#    midi.NoteOnEvent(tick=27, channel=0, data=[18, 139]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[26, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[115, 0]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[22, 28]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[41, 0]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[90, 36]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[106, 213]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[39, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[65, 19]),
#    midi.NoteOffEvent(tick=30, channel=0, data=[61, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[78, 36]),
#    midi.NoteOnEvent(tick=27, channel=0, data=[99, 14]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[42, 105]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[124, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[45, 11]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[68, 203]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[67, 100]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[115, 98]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[110, 97]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[2, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[115, 133]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[65, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[93, 0]),
#    midi.NoteOnEvent(tick=37, channel=0, data=[38, 216]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[114, 106]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[99, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[86, 0]),
#    midi.NoteOffEvent(tick=57, channel=0, data=[84, 0]),
#    midi.NoteOffEvent(tick=45, channel=0, data=[114, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[43, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[78, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[22, 0]),
#    midi.NoteOffEvent(tick=83, channel=0, data=[115, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[106, 0]),
#    midi.NoteOffEvent(tick=80, channel=0, data=[81, 0]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=59, channel=0, data=[45, 0]),
#    midi.NoteOffEvent(tick=58, channel=0, data=[42, 0]),
#    midi.NoteOffEvent(tick=45, channel=0, data=[58, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[67, 0]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[56, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[110, 0]),
#    midi.NoteOffEvent(tick=40, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=107, channel=0, data=[38, 0]),
#    midi.NoteOffEvent(tick=61, channel=0, data=[68, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[7]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[77, 235]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[5, 211]),
#    midi.NoteOnEvent(tick=32, channel=0, data=[46, 233]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[37, 252]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[56, 255]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[106, 111]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[55, 59]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[21, 67]),
#    midi.NoteOnEvent(tick=30, channel=0, data=[26, 150]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[95, 4]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[26, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[62, 131]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[21, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[92, 225]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[96, 63]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[81, 180]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[75, 120]),
#    midi.NoteOnEvent(tick=30, channel=0, data=[62, 125]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[0, 117]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[42, 137]),
#    midi.NoteOnEvent(tick=68, channel=0, data=[26, 1]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[53, 177]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[22, 145]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[103, 91]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[108, 144]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[84, 192]),
#    midi.NoteOnEvent(tick=61, channel=0, data=[43, 95]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[5, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[108, 8]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[96, 0]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[77, 117]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[86, 15]),
#    midi.NoteOnEvent(tick=29, channel=0, data=[19, 85]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[22, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[108, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[67, 4]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[49, 117]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[49, 0]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[68, 233]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[56, 98]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[51, 123]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[56, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[9, 97]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[57, 209]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[41, 244]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[0, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[56, 191]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[4, 245]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[95, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[101, 20]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[118, 78]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[55, 0]),
# ...
#    midi.NoteOnEvent(tick=0, channel=0, data=[48, 62]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[7, 155]),
#    midi.NoteOnEvent(tick=14, channel=0, data=[124, 243]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[14, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[91, 0]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[3, 137]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[17, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[35, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[32, 118]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[67, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[29, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[93, 93]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[86, 255]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[34, 189]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[25, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[80, 108]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[112, 84]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[58, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[92, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[102, 69]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[15, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[97, 168]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[17, 101]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[65, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[94, 0]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[103, 209]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[100, 210]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[95, 253]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[102, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[91, 215]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[126, 0]),
#    midi.NoteOnEvent(tick=28, channel=0, data=[99, 208]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[86, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[124, 0]),
#    midi.NoteOffEvent(tick=37, channel=0, data=[70, 0]),
#    midi.NoteOffEvent(tick=36, channel=0, data=[0, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[103, 0]),
#    midi.NoteOffEvent(tick=51, channel=0, data=[116, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[60, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[114, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=52, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[48, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[100, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[49, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[112, 0]),
#    midi.NoteOffEvent(tick=49, channel=0, data=[91, 0]),
#    midi.NoteOffEvent(tick=177, channel=0, data=[7, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[3, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=45, channel=0, data=[108, 0]),
#    midi.NoteOffEvent(tick=83, channel=0, data=[17, 0]),
#    midi.NoteOffEvent(tick=75, channel=0, data=[34, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[97, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[95, 0]),
#    midi.NoteOffEvent(tick=47, channel=0, data=[99, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[126]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[104, 7]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[74, 75]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[61, 246]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[102, 133]),
#    midi.NoteOffEvent(tick=41, channel=0, data=[102, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[29, 123]),
#    midi.NoteOnEvent(tick=39, channel=0, data=[92, 117]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[6, 191]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[28, 122]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[28, 0]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[104, 157]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[9, 252]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[81, 44]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[118, 28]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[81, 0]),
#    midi.NoteOnEvent(tick=57, channel=0, data=[20, 61]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[17, 22]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[74, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[6, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[54, 142]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[118, 0]),
#    midi.NoteOffEvent(tick=21, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[20, 0]),
#    midi.NoteOnEvent(tick=57, channel=0, data=[108, 162]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[122, 83]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[108, 29]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[122, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[70, 39]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[117, 218]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[106, 219]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[9, 119]),
#    midi.NoteOffEvent(tick=28, channel=0, data=[92, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[78, 124]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[57, 66]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[87, 171]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[9, 130]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[2, 224]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[55, 41]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[2, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[101, 48]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[70, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[55, 102]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[17, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[53, 75]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[19, 39]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[78, 0]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[32, 252]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[53, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[22, 216]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[108, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[42, 172]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[24, 38]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[9, 236]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[57, 0]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[100, 140]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[49, 165]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[102, 218]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[115, 32]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[95, 101]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[87, 154]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[66, 255]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[73, 80]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[77, 125]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[33, 195]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[33, 0]),
#    midi.NoteOnEvent(tick=64, channel=0, data=[78, 131]),
#    midi.NoteOnEvent(tick=24, channel=0, data=[13, 48]),
#    midi.NoteOffEvent(tick=29, channel=0, data=[104, 0]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[74, 202]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[100, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[61, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[115, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[67, 147]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[7, 44]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[77, 115]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[15, 179]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[2, 239]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[54, 0]),
#    midi.NoteOnEvent(tick=18, channel=0, data=[20, 31]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[49, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=66, channel=0, data=[73, 0]),
#    midi.NoteOffEvent(tick=99, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=52, channel=0, data=[2, 0]),
#    midi.NoteOffEvent(tick=59, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[42, 0]),
#    midi.NoteOffEvent(tick=48, channel=0, data=[106, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[101, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[87, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[78, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[32, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[24, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[9, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[74, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[22, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[20, 0]),
#    midi.NoteOffEvent(tick=59, channel=0, data=[95, 0]),
#    midi.NoteOffEvent(tick=87, channel=0, data=[7, 0]),
#    midi.NoteOffEvent(tick=217, channel=0, data=[67, 0]),
#    midi.NoteOffEvent(tick=79, channel=0, data=[15, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])]),
#  midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[8, 227, 124]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[127]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[73, 203]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[86, 85]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[2, 7]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[80, 225]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[85, 74]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[107, 148]),
#    midi.NoteOnEvent(tick=9, channel=0, data=[32, 249]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[95, 204]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[6, 113]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[31, 71]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[39, 157]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[95, 0]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[35, 133]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[110, 3]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[90, 9]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[4, 251]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[96, 96]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[11, 125]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[90, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[98, 0]),
#    midi.NoteOnEvent(tick=23, channel=0, data=[69, 79]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[19, 122]),
#    midi.NoteOnEvent(tick=15, channel=0, data=[121, 207]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[90, 89]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[28, 156]),
#    midi.NoteOnEvent(tick=11, channel=0, data=[114, 153]),
#    midi.NoteOnEvent(tick=17, channel=0, data=[96, 237]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[73, 0]),
#    midi.NoteOnEvent(tick=13, channel=0, data=[96, 11]),
#    midi.NoteOnEvent(tick=19, channel=0, data=[53, 166]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[79, 154]),
#    midi.NoteOffEvent(tick=66, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[110, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[114, 0]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[19, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[39, 43]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[6, 62]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[104, 190]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[68, 95]),
#    midi.NoteOnEvent(tick=16, channel=0, data=[123, 231]),
#    midi.NoteOnEvent(tick=31, channel=0, data=[30, 114]),
#    midi.NoteOnEvent(tick=28, channel=0, data=[60, 48]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[15, 106]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[86, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[68, 5]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[69, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[31, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[39, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[96, 0]),
#    midi.NoteOnEvent(tick=21, channel=0, data=[93, 182]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[51, 218]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[99, 62]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[32, 0]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[13, 180]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[42, 128]),
#    midi.NoteOnEvent(tick=12, channel=0, data=[85, 74]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[79, 234]),
#    midi.NoteOnEvent(tick=22, channel=0, data=[77, 239]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[82, 249]),
#    midi.NoteOnEvent(tick=25, channel=0, data=[79, 100]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[59, 247]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[120, 220]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[79, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[15, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=41, channel=0, data=[120, 0]),
#    midi.NoteOnEvent(tick=8, channel=0, data=[123, 218]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[107, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[123, 0]),
#    midi.NoteOffEvent(tick=27, channel=0, data=[104, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[60, 0]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[29, 254]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[35, 148]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[49, 94]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[59, 0]),
#    midi.NoteOnEvent(tick=20, channel=0, data=[27, 63]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[21, 214]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[93, 80]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[37, 9]),
#    midi.NoteOnEvent(tick=10, channel=0, data=[89, 27]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[8, 225]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[121, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[2, 0]),
#    midi.NoteOffEvent(tick=43, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=54, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[49, 0]),
#    midi.NoteOffEvent(tick=36, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[42, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[53, 0]),
#    midi.NoteOffEvent(tick=35, channel=0, data=[8, 0]),
#    midi.NoteOffEvent(tick=80, channel=0, data=[99, 0]),
#    midi.NoteOffEvent(tick=63, channel=0, data=[6, 0]),
#    midi.NoteOffEvent(tick=107, channel=0, data=[68, 0]),
#    midi.NoteOffEvent(tick=90, channel=0, data=[93, 0]),
#    midi.NoteOffEvent(tick=122, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=39, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=60, channel=0, data=[21, 0]),
#    midi.NoteOffEvent(tick=43, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=75, channel=0, data=[89, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])])])
