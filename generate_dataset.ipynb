# %%
import midi
import numpy as np
import h5py
class MidiContainer:
    '''
    The MidiContainer class contains a vector representation of 
    the midi track to be fed to our neural net. It is a 67 x n matrix,
    contents specified in the README. 
    '''
    def __init__(self):
        self.data = np.array([], dtype=np.int64).reshape(66,0) 
        self.curr_bpm = 120
        self.curr_instrument = 0
        self.abs_time = 0
        self.active_pitches = {} #[pitch] = (velocity, time note was turned on)
        
    def note_to_vector(self, pitch, time):
        velocity = self.active_pitches[pitch][0]
        note_start = self.active_pitches[pitch][1]
        return np.vstack((self.curr_instrument, pitch, velocity, time + self.abs_time - note_start))
    
    def add_data(self, note_vector, note_start):
        event_column = np.vstack((note_start, self.curr_bpm, note_vector, np.ones((60,1))*-1))
        self.data = np.hstack((self.data, event_column))
    
    def combine_tracks(self):
        self.data = self.data.T[self.data.T[:, 0].argsort()].T #maybe we dont need so many transposes
        prev_duration = -1
        edit_index = 0 
        i = 0
        delete_this = []
        old_inst = self.data[2,0]
        for col in self.data.T:
            curr_duration = col[0]
            if curr_duration == prev_duration:
                for ni in xrange(2,67,4):
                    note_vec = col[ni:ni+4]
                    curr_inst = note_vec[0] if note_vec.any() else -1
                    if np.sum(note_vec) > 0 and curr_inst != old_inst:
                        i_rep = np.where(self.data[:,edit_index] == -1)[0][0]
                        self.data[i_rep:i_rep+4, edit_index] = note_vec
                        delete_this.append(i)
            else:
                old_inst = col[2]
                edit_index = i
            i += 1 
            prev_duration = curr_duration
            
        mask = np.ones(self.data.shape, np.bool)
        mask[:,delete_this] = 0
        self.data = self.data[mask].reshape(66,-1)
       
                
    
def midi_to_vector(fname):
    '''
    Given a filename of a midi to read, returns a MidiContainer object of its vector representation.
    '''
    pattern = midi.read_midifile(fname)
    midi_vector = MidiContainer()
    for track in pattern:
        midi_vector.abs_time = 0
        for event in track:
            if isinstance(event, midi.SetTempoEvent): 
                midi_vector.curr_bpm = event.get_bpm()
            if isinstance(event, midi.EndOfTrackEvent): #first metadata track
                continue 
            if isinstance(event, midi.ProgramChangeEvent):
                midi_vector.curr_instrument = event.get_value()
            if isinstance(event, midi.NoteOnEvent):
                midi_vector.abs_time += event.tick
                midi_vector.active_pitches[event.get_pitch()] = (event.get_velocity(), midi_vector.abs_time)
            if isinstance(event, midi.NoteOffEvent):
                pitch = event.get_pitch()
                time = event.tick
                if pitch in midi_vector.active_pitches:
                    note_vec = midi_vector.note_to_vector(pitch, time)
                    midi_vector.add_data(note_vec, midi_vector.active_pitches[pitch][1]) #ugh bad data abstraction
                    midi_vector.active_pitches.pop(pitch, None)
                    midi_vector.abs_time += event.tick
                    
#     assert midi_vector.data.all(), "Read midifile is empty."            
    midi_vector.combine_tracks()        
    return midi_vector

def vector_to_midi(vector):
    '''Given a np array (vector.data), returns a python midi pattern'''
    pattern = midi.Pattern(resolution=192)
    #first, separate tracks
    tracklist = {}
    for i in xrange(2,vector.shape[0],4):
        for j in xrange(0, vector.shape[1]):
            track = vector[i:i+4,j]
            if np.sum(track) > 0:
                instrument = int(track[0])
                if instrument not in tracklist:
                    tracklist[instrument] = np.vstack((vector[0:2,j].reshape(-1,1), track.reshape(-1,1)))
                else: 
                    tracklist[instrument] = np.hstack((tracklist[instrument], np.vstack((vector[0:2,j].reshape(-1,1), track.reshape(-1,1)))))


    for k, track in tracklist.iteritems():
        miditrack = midi.Track()
        pattern.append(miditrack)
        bpm = track[1,0]
        tempoevent = midi.SetTempoEvent(tick=0, bpm=bpm)
        miditrack.append(tempoevent)
        instrument = int(track[2,0])
        fontevent = midi.ProgramChangeEvent(tick=0, value=instrument)
        miditrack.append(fontevent)
        if not np.array_equal(bpm * np.ones(track.shape[1]), track[1,:]):
            print 'Tempo changes. Code assumes it doesn\'t. Contact Jingyi.'
        
        event_tick = 0   
        track_duration = np.max(track[0,:] + track[-1,:])
        active_notes = {}
        start_times = track[0,:]
        for t in xrange(0, int(track_duration)+1):
            for pitch in active_notes:
                active_notes[pitch] -= 1
            
            negs = [k for k,v in active_notes.iteritems() if v < 0]
            for n in negs:
                active_notes.pop(n)
                
            while 0 in active_notes.values():
                pitches = [k for k,v in active_notes.iteritems() if v == 0]
                for pitch in pitches:
                    off = midi.NoteOffEvent(tick=t - event_tick, pitch=pitch)
                    miditrack.append(off)
                    active_notes.pop(pitch)
                    event_tick = t
                    
            #run through track to add on/off events
            if t in start_times:
                ni = np.where(t == start_times)
                for n in ni[0]:
                    note = track[:, n]
                    start_time = int(note[0])
                    pitch = int(note[3])
                    velocity = int(note[4])
                    duration = int(note[5])
                    active_notes[pitch] = duration
                    on = midi.NoteOnEvent(tick = t - event_tick, velocity=velocity, pitch=pitch)
                    miditrack.append(on)
                    event_tick = start_time
                    
        miditrack.append(midi.EndOfTrackEvent(tick=0))
    return pattern

# %%
path = '/Users/noon/Desktop/midis/broadway/' #change me, make sure to make a 'data' folder
import os
i = 0
b = 1
for fname in os.listdir(path):
    if '.mid' in fname.lower():
        try:
            vectorized = midi_to_vector(path+fname)
            h5f = h5py.File(path+'data/'+fname[0:-4]+'.h5', 'w')
            h5f.create_dataset('dataset_1', data=vectorized.data)
            h5f.close()
            print 'SUCCESS! finished writing for ', fname
            i += 1
        except (TypeError, AssertionError, IndexError) as e:
            print e, fname
            b += 1
            continue
b-=1
print 'got ', i*1.0/(i+b) * 100, '% working'
# Out:
# SUCCESS! finished writing for  aliaskyu.mid
# index 0 is out of bounds for axis 1 with size 0 almostlk.mid
# index 0 is out of bounds for axis 1 with size 0 america.mid
# SUCCESS! finished writing for  angel.mid
# index 0 is out of bounds for axis 1 with size 0 baliha'i.mid
# index 0 is out of bounds for axis 1 with size 0 belinyou.mid
# index 0 is out of bounds for axis 1 with size 0 bring.mid
# SUCCESS! finished writing for  broadway.mid
# index 0 is out of bounds for axis 1 with size 0 cabaret.mid
# index 0 is out of bounds for axis 1 with size 0 castle.mid
# SUCCESS! finished writing for  chess.mid
# index 0 is out of bounds for axis 1 with size 0 close.mid
# index 0 is out of bounds for axis 1 with size 0 crapshot.mid
# SUCCESS! finished writing for  ditesmoi.mid
# index 0 is out of bounds for axis 1 with size 0 dolly.mid
# index 0 is out of bounds for axis 1 with size 0 domphan.mid
# index 0 is out of bounds for axis 1 with size 0 dphanrk.mid
# SUCCESS! finished writing for  eapoe.mid
# SUCCESS! finished writing for  edelweis.mid
# SUCCESS! finished writing for  eternal.mid
# SUCCESS! finished writing for  evita.mid
# SUCCESS! finished writing for  fantast.mid
# SUCCESS! finished writing for  getoknow.mid
# index 0 is out of bounds for axis 1 with size 0 guydolls.mid
# SUCCESS! finished writing for  hapevaf.mid
# index 0 is out of bounds for axis 1 with size 0 hearsing.mid
# SUCCESS! finished writing for  hernando.mid
# SUCCESS! finished writing for  heythere.mid
# SUCCESS! finished writing for  hndohdwy.mid
# SUCCESS! finished writing for  hopeless.mid
# index 0 is out of bounds for axis 1 with size 0 magctodo.mid
# SUCCESS! finished writing for  maria.mid
# SUCCESS! finished writing for  mhbring.mid
# SUCCESS! finished writing for  music.mid
# SUCCESS! finished writing for  noinlove.mid
# SUCCESS! finished writing for  oncewasa.mid
# SUCCESS! finished writing for  onceyear.mid
# index 0 is out of bounds for axis 1 with size 0 peoplew.mid
# index 0 is out of bounds for axis 1 with size 0 phantom2.mid
# index 0 is out of bounds for axis 1 with size 0 river.mid
# SUCCESS! finished writing for  smaltalk.mid
# SUCCESS! finished writing for  steam.mid
# SUCCESS! finished writing for  tinhorn.mid
# SUCCESS! finished writing for  youcando.mid
# got  59.0909090909 % working

# %%
def gen_channel():
    font = np.random.random_integers(0,127) * np.ones((1,500))
    note = np.random.random_integers(0,127, size=(1,500))
    vel = np.random.random_integers(0,255, size=(1,500))
    duration = np.random.random_integers(0,1000, size=(1,500))
    return np.vstack((font, note, vel, duration))

def gen_random_midi():
    times = np.random.random_integers(0,1000, size=(1,500))
    bpm = np.random.random_integers(50,300) * np.ones((1,500))
    midi = np.vstack((times,bpm))
    for i in xrange(0,16):
        midi = np.vstack((midi, gen_channel()))
    return midi

# %%
#random generation test

data = gen_random_midi()
print data
pattern = vector_to_midi(data)
print pattern
midi.write_midifile('rando.mid', pattern)
# Out:
# [[ 882.  480.  432. ...,  185.  138.  591.]
#  [ 200.  200.  200. ...,  200.  200.  200.]
#  [ 101.  101.  101. ...,  101.  101.  101.]
#  ...,
#  [  95.   58.    0. ...,   39.   95.  121.]
#  [  27.  248.   68. ...,  228.   56.  102.]
#  [  65.  140.  896. ...,  511.  369.   58.]]
# midi.Pattern(format=1, resolution=192, tracks=\
# [midi.Track(\
#   [midi.SetTempoEvent(tick=0, data=[4, 147, 224]),
#    midi.ProgramChangeEvent(tick=0, channel=0, data=[96]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[69, 246]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[82, 224]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[59, 191]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[81, 90]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[69, 92]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[38, 140]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[19, 116]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[36, 141]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[36, 115]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[54, 199]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[59, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[14, 191]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[95, 7]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[112, 83]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[61, 179]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[102, 114]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[16, 8]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[83, 223]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[127, 125]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[58, 167]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[70, 20]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[107, 209]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[42, 187]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[7, 40]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[48, 161]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[69, 202]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[31, 223]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[9, 143]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[112, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[12, 158]),
#    midi.NoteOnEvent(tick=8, channel=0, data=
 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[0, 103]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[14, 240]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[18, 72]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[30, 4]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[59, 36]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[107, 187]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[115, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[75, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[37, 23]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[113, 183]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[56, 122]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[105, 86]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[40, 250]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[44, 152]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[108, 184]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[32, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[60, 102]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[107, 106]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[72, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[88, 51]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[90, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[16, 89]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[59, 227]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[32, 203]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[127, 22]),
#    midi.NoteOnEvent(tick=6, channel=0, data=[81, 60]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[10, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[84, 54]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[115, 206]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[39, 3]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[89, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[77, 172]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[33, 13]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[116, 106]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[118, 132]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[73, 6]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[16, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[72, 133]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[106, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[52, 229]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[85, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[127, 113]),
#    midi.NoteOnEvent(tick=7, channel=0, data=[17, 228]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[22, 196]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[29, 183]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[90, 206]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[32, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[117, 153]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[86, 231]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[68, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[46, 195]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[47, 15]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[9, 172]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[12, 116]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[63, 33]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[49, 0]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[40, 116]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[7, 7]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[11, 190]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[40, 89]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[34, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[52, 236]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[83, 63]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[102, 204]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[66, 177]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[3, 0]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[127, 192]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[71, 157]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[79, 53]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[116, 129]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[84, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[90, 195]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[81, 242]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[46, 182]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[10, 189]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[99, 165]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[112, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[105, 248]),
#    midi.NoteOnEvent(tick=4, channel=0, data=[121, 132]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[14, 219]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[84, 42]),
#    midi.NoteOnEvent(tick=5, channel=0, data=[6, 253]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[65, 120]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[24, 107]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[91, 102]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[40, 150]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[52, 0]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[25, 128]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[5, 103]),
#    midi.NoteOnEvent(tick=2, channel=0, data=[54, 133]),
#    midi.NoteOnEvent(tick=0, channel=0, data=[8, 119]),
#    midi.NoteOnEvent(tick=1, channel=0, data=[115, 127]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[56, 239]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[38, 0]),
#    midi.NoteOnEvent(tick=3, channel=0, data=[94, 84]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[10, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[69, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[22, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[48, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[21, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[124, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[100, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[25, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[120, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[17, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[6, 0]),
#    midi.NoteOffEvent(tick=39, channel=0, data=[56, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[62, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[81, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[9, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[123, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[31, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[125, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[26, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[39, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[91, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[126, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[15, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[94, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[44, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[118, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[107, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[114, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[122, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[43, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[71, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[42, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[116, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[108, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[7, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[36, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[110, 0]),
#    midi.NoteOffEvent(tick=25, channel=0, data=[45, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[115, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[92, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[41, 0]),
#    midi.NoteOffEvent(tick=20, channel=0, data=[97, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[46, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[61, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[47, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[0, 0]),
#    midi.NoteOffEvent(tick=36, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=16, channel=0, data=[99, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[73, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[54, 0]),
#    midi.NoteOffEvent(tick=17, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[103, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[33, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[127, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=
 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[23, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[122, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[71, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[40, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[88, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[77, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[90, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[125, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[37, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[58, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[117, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[118, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[97, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[80, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[18, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[7, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[82, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[96, 0]),
#    midi.NoteOffEvent(tick=22, channel=0, data=[34, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[51, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[75, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[112, 0]),
#    midi.NoteOffEvent(tick=32, channel=0, data=[94, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[95, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[36, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[2, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[12, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[120, 0]),
#    midi.NoteOffEvent(tick=24, channel=0, data=[31, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[78, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[124, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[30, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[105, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[46, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[66, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[119, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[35, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[63, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[59, 0]),
#    midi.NoteOffEvent(tick=32, channel=0, data=[17, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[111, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[114, 0]),
#    midi.NoteOffEvent(tick=14, channel=0, data=[48, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[5, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[6, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[39, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[65, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[4, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[121, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[13, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[104, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[101, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[62, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[92, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[87, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[10, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[85, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[19, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[103, 0]),
#    midi.NoteOffEvent(tick=13, channel=0, data=[84, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[0, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[64, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[67, 0]),
#    midi.NoteOffEvent(tick=15, channel=0, data=[89, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[74, 0]),
#    midi.NoteOffEvent(tick=26, channel=0, data=[49, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[57, 0]),
#    midi.NoteOffEvent(tick=3, channel=0, data=[123, 0]),
#    midi.NoteOffEvent(tick=38, channel=0, data=[29, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[27, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[28, 0]),
#    midi.NoteOffEvent(tick=12, channel=0, data=[86, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[126, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[15, 0]),
#    midi.NoteOffEvent(tick=4, channel=0, data=[109, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[11, 0]),
#    midi.NoteOffEvent(tick=9, channel=0, data=[73, 0]),
#    midi.NoteOffEvent(tick=11, channel=0, data=[47, 0]),
#    midi.NoteOffEvent(tick=0, channel=0, data=[91, 0]),
#    midi.NoteOffEvent(tick=10, channel=0, data=[69, 0]),
#    midi.NoteOffEvent(tick=8, channel=0, data=[16, 0]),
#    midi.NoteOffEvent(tick=33, channel=0, data=[72, 0]),
#    midi.NoteOffEvent(tick=18, channel=0, data=[98, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[50, 0]),
#    midi.NoteOffEvent(tick=31, channel=0, data=[55, 0]),
#    midi.NoteOffEvent(tick=2, channel=0, data=[43, 0]),
#    midi.NoteOffEvent(tick=6, channel=0, data=[106, 0]),
#    midi.NoteOffEvent(tick=5, channel=0, data=[41, 0]),
#    midi.NoteOffEvent(tick=23, channel=0, data=[99, 0]),
#    midi.NoteOffEvent(tick=32, channel=0, data=[14, 0]),
#    midi.NoteOffEvent(tick=19, channel=0, data=[1, 0]),
#    midi.NoteOffEvent(tick=41, channel=0, data=[38, 0]),
#    midi.NoteOffEvent(tick=32, channel=0, data=[54, 0]),
#    midi.NoteOffEvent(tick=1, channel=0, data=[102, 0]),
#    midi.NoteOffEvent(tick=7, channel=0, data=[115, 0]),
#    midi.EndOfTrackEvent(tick=0, data=[])])])
